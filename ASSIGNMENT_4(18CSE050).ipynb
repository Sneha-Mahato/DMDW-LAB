# %% [markdown]
# <a href="https://colab.research.google.com/github/Sneha-Mahato/DMDW-LAB/blob/main/ASSIGNMENT_4(18CSE050).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment - 4
# # Data Visualization

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("https://raw.githubusercontent.com/archana1822/DMDW-Lab/main/Toyota.csv")
data.head()
# Out:
#    Unnamed: 0  Price   Age     KM  ... Automatic    CC  Doors  Weight
# 0           0  13500  23.0  46986  ...         0  2000  three    1165
# 1           1  13750  23.0  72937  ...         0  2000      3    1165
# 2           2  13950  24.0  41711  ...         0  2000      3    1165
# 3           3  14950  26.0  48000  ...         0  2000      3    1165
# 4           4  13750  30.0  38500  ...         0  2000      3    1170
#
# [5 rows x 11 columns]

# %%
plt.scatter(data['Age'],data['Price'])
plt.xlabel('Age')
plt.ylabel('Price')
plt.show()

# %%
data.hist(figsize = (20,30))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f0d1c4c5860>,
# ...
#       dtype=object)

# %%
counts = [979, 120, 12]
fuelType = ('Petrol', 'Diesel', 'CNG')
index = np.arange(len(fuelType))
plt.bar(index, counts, color=['red', 'blue', 'cyan'])
plt.title('Bar plot of fuel types')
plt.xlabel('Fuel Types')
plt.ylabel('Frequency')
plt.xticks(index, fuelType, rotation = 90)
plt.show()

# %%
sns.set(style="darkgrid")
sns.regplot(x=data['Age'],y=data['Price'])

# %%
sns.distplot(data['Age'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.countplot(x="FuelType", data=data)

# %%
sns.countplot(x="FuelType", data=data, hue = "Automatic")

# %%
sns.boxplot(y=data["Price"])

# %%
sns.boxplot(x=data['FuelType'], y=data["Price"])

# %%
sns.pairplot(data, kind="countplot")
plt.show()
